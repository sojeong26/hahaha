# %% [markdown]
# <a href="https://colab.research.google.com/github/sojeong26/hahaha/blob/airecycle/recycling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !pip install bing-image-downloader

# %%
from bing_image_downloader import downloader
import shutil
from pathlib import Path
import os

def download_images(keyword, num_images, file_name):
    output_directory = "images"

    # 출력 디렉토리 생성
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # 이미지 다운로드 시도
    downloader.download(keyword, limit=num_images, output_dir=output_directory,
                        adult_filter_off=True, force_replace=False, timeout=60)

    root = Path().cwd() / output_directory / keyword  # keyword를 포함한 디렉토리로 변경
    downloaded_files = list(root.glob("*.*"))

    print(f"다운로드된 파일 경로: {root}")
    print(f"다운로드된 파일 목록: {downloaded_files}")

    if not downloaded_files:
        print("이미지가 다운로드되지 않았습니다. 검색어와 인터넷 연결을 확인하세요.")
        return

    # 다운로드된 파일 이름 변경
    for i, file in enumerate(downloaded_files):
        extension = file.suffix
        new_file_name = f"{file_name}{i+1}{extension}"
        new_file_path = root / new_file_name
        file.rename(new_file_path)

    print(f"{len(downloaded_files)}개의 이미지가 다운로드되었습니다.")

# 이미지 다운로드를 위한 변수 설정 및 함수 호출
keyword = "plasticbottle"
num_images = 100
file_name = "plastic_bottle"

# 함수 호출
download_images(keyword, num_images, file_name)
# Out:
# [%] Downloading Images to /content/drive/My Drive/23-2_modeling_CV_A/model/images/plasticbottle
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://pluspng.com/img-png/water-bottle-png-image-39990-1700.png
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://images.freeimages.com/images/large-previews/620/plastic-bottle-1327399.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://bernardlab.com/wp-content/uploads/2021/01/plastic-bottles.png
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://pluspng.com/img-png/about-us-1738.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i5.walmartimages.com/asr/83568193-2418-40f0-8367-4fd80481e2f8_1.fc5284020d9e9b9bcd45d777a9e62bb5.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://www.howitworksdaily.com/wp-content/uploads/2015/09/plastic-bottles.jpg
# [%] File Downloaded !
#
# ...

# %%
# !git clone https://github.com/sojeong26/23-2_modeling_CV_A.git
# Out:
# fatal: destination path '23-2_modeling_CV_A' already exists and is not an empty directory.

# %%
cd/content/drive/MyDrive/23-2_modeling_CV_A/model
# Out:
# /content/drive/MyDrive/23-2_modeling_CV_A/model

# %%
# !git config --global user.email 'cowper04@gmail.com'
# !git config --global user.name 'sojeong26'

# %%
# !pip install -r requirements.txt

# %%
# 종속성 설치
# !pip install -U torch torchvision
# !pip install git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
# !pip install matplotlib tqdm numpy
# Out:
# ...
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-42hqy95b
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-42hqy95b
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !python train.py --data data.yaml --weights yolov5s.pt --img 640
# Out:
# 2024-06-21 07:55:53.552873: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-21 07:55:53.553007: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-21 07:55:53.554759: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# 종속성 설치
# !pip install matplotlib tqdm numpy opencv-python-headless

# %%
import subprocess

# 필요한 변수 설정
weights = "yolov5s.pt"  # 학습된 모델의 가중치 파일 경로
data_yaml = "coco128.yaml"  # 데이터셋에 대한 YAML 파일 경로
img_size = 640  # 입력 이미지 크기

# subprocess를 이용하여 val.py 실행
subprocess.run([
    'python', 'val.py',
    '--weights', weights,
    '--data', data_yaml,
    '--img', str(img_size)
])
# Out:
# CompletedProcess(args=['python', 'val.py', '--weights', 'yolov5s.pt', '--data', 'coco128.yaml', '--img', '640'], returncode=1)

# %%
import subprocess

command = [
    'python', 'detect.py',
    '--weights', 'yolov5s.pt',
    '--source', '0',
    '--imgsz', '640',
    '--conf-thres', '0.25'
]

try:
    subprocess.run(command, check=True)
except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
